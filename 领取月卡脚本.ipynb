# %%
import requests

url = 'https://fco.qq.com/cp/a20200520card/index.html'

try:
    response = requests.get(url)
    response.raise_for_status()  # 确保请求成功
    print(response.text)  # 打印网页内容
except requests.RequestException as e:
    print(e)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# <meta charset="gbk">
# <meta name="robots" content="all">
# <meta name="author" content="Tencent-CP" />
# <meta name="Copyright" content="Tencent">
# <meta name="Description" content="¡¶FC Online¡·¹Ù·½ÍøÕ¾¡£EA SPORTS FCÑÐ·¢£¬ÌÚÑ¶ÓÎÏ·´úÀíÔËÓªµÄÈ«Çò×îÊÜ»¶Ó­ÕæÊµ3D×ãÇòÍøÓÎÏµÁÐ£¬ÓµÓÐ±ÆÕæµÄÇòÔ±ÐÎÏó£¬·á¸»µÄÇòÔ±Çò¶ÓÑø³É£¬¿ìËÙÆ¥ÅäÈ«ÇòÍæ¼Ò£¬´ø¸øÄã³¬ÄâÕæÂÌÒðÀÖÈ¤¡£">
# <meta name="Keywords" content="FC Online,FC Online¹Ù·½ÏÂÔØ,FC OnlineÏÂÔØ,×ãÇòÔÚÏß,FC Online,3D,×ãÇò,ÍøÓÎ,ÌåÓý,ÊÀ½ç±­,Å·¹Ú,ÖÐ³¬,ÇòÔ±,Ã·Î÷,CÂÞ,ÄÚÂí¶û,×ª»á,µç×Ó¾º¼¼,ÌÚÑ¶,ÍøÂçÓÎÏ·">
# <title>ÈÙÒ«ÂÌÒðÔÂ¿¨- FC Online¹Ù·½ÍøÕ¾ - ÌÚÑ¶ÓÎÏ·</title>
# 	<script>
# 		//httpsÌø×ª
# 		//var targetProtocol = "https:";
# 		//if (window.location.protocol != targetProtocol) window.location.href = targetProtocol + window.location.href.substring(window.location.protocol.length);
# 	</script>
#
# <style>
# body,div,dl,dt,dd,ul,ol,li,h1,h2,h3,h4,h5,h6,pre,form,fieldset,input,textarea,p,blockquote,th,td{margin:0;padding:0;}
# table{border-collapse:collapse;border-spacing:0;}
# address,caption,cite,code,dfn,em,strong,th,var{font-weight:normal;font-style:normal;}
# ol,ul{list-style:none;}
# caption,th{text-align:left;}
# h1,h2,h3,h4,h5,h6{font-weight:normal;font-size:100%;}
# q:before,q:after{content:'';}
# fieldset,img,abbr,acronym{border:0;}
# iframe{position: absolute;}
# /*Ò³ÃæÑùÊ½*/
# .c:before,.c:after {content:"";display:table;}
# .c:after {clear:both;}
# .c {zoom:1;}
# body {font:12px/1.5 'myFont','simhei','simsun';text-align:justify;padding-top:42px !important;background-color:#d3d8dc;overflow-x: hidden;}
# @font-face {
# 	font-family: 'myFont';
# 	src: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/fzlthk.ttf);
# }
# @font-face {
# 	font-family: 'font';
# 	src: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/font.ttf);
# }
# a {text-decoration:none;overflow:hidden;}
# a:hover {text-decoration:none;}
# .wrap,.wrap1,#footer_ied{min-width:1200px;width:100%;_width:expression((document.documentElement.clientWidth||document.body.clientWidth)<1202?'1200px':'');}
# .ost_box,.act-nav{min-width: 1200px !important;}
# #_overlay_{min-width: 1200px !important;}
# .wrap{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/rp1.jpg) no-repeat 50% 0;}
# .wrap1{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/rp2.jpg) no-repeat 50% 752px;padding-bottom: 50px;}
# .sp{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/sp.png) no-repeat 50% 0;}
# .container{width:1200px;margin:0 auto;}
# .pr{position:relative;}
# .pa{position:absolute;}
# .hide {display:block;width:0;height:0;overflow:hidden;}
# .db{display:block;text-indent:-9999em;}
# .fl{float: left;}
# .fr{float: right;}
# img{display: block;margin: 0 auto;}
# :focus{outline: none;}
# /*footer*/
# #afooter{width:100%;text-align:center;line-height:20px;color:#cacaca;background-color:#000;padding: 20px 0;min-width: 1200px;}
# #afooter a{ color: #cacaca;}
# /* head */
# .head{height:774px;}
# .logo{background:url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/logo_fco.png) no-repeat 50% 0;width:364px;height:53px;top:86px;left: 50%;transform: translateX(-50%);}
# .slo{width: 1114px;height: 300px;top:219px;overflow: hidden;}
# .slo img{animation:fadeInDownBig  1.0s ease-in-out both;width: 1114px;height: 300px;}
# .tag{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/tag1.png) no-repeat 50% 0;width: 233px;height:183px;top:225px;right:18px;animation: bounceIndown  1.5s .4s ease both;}
# .tag1{height:161px;top:694px;text-align: center;overflow: hidden;}
# .tag1 span{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/tag2.png) no-repeat 50% 0;width:958px;height:161px;animation:fadeIntopBig 1.0s ease-in-out both;display: block;}
# @keyframes fadeInDownBig{
# 	0%{opacity:0;transform:translate3d(0,-2000px,0)}
# 	to{opacity:1;transform:translateZ(0)}}
# @keyframes fadeIntopBig{
# 	0%{opacity:0;transform:translate3d(0,2000px,0)}
# 	to{opacity:1;transform:translateZ(0)}}
# @keyframes bounceIndown {
# 	0% {opacity: 0;transform: translateY(-3000px);}
# 	60% {opacity: 1;transform: translateY(25px);}
# 	75% {transform: translateY(-10px);}
# 	90% {transform: translateY(5px);}
# 	100% {transform: translateY(0);}}
# .login{color: #ffffff;font-size:24px;text-align: center;width: 100%;position: absolute;bottom:130px;left: 0;}
# .login a{color:#07f468;}
# /*part1*/
# .content{padding-bottom:40px;}
# .tab_nav{width: 961px;margin: 0 auto;}
# .tab_nav a{width: 417px; height:137px;box-sizing: border-box;}
# .nav1{background:url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/nav1.png) no-repeat 50% 0;padding:30px 10px 0 100px;}
# .nav2{background:url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/nav2.png) no-repeat 50% 0;padding:30px 10px 0 100px;}
# .sub_tit{color:#fff;font-size:60px;font-weight: bold;line-height: 62px;height: 62px;}
# .tab_nav a span{color:#151616;font-size:16px;line-height:24px;height: 24px;display: block;
# background-color: #00ff68;width: 73px;height: 24px;line-height: 24px;text-align: center;}
# /* .tab_nav .nav2 span{color:#606266;text-align: left;} */
# /* .tab_nav a.act span{color:#ec4c2b;} */
# .tab_nav span{margin-top:-27px;}
# .jihuo{display: none !important;}
# .nav1.act{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/nav1_act.png) no-repeat 50% 0;}
# .nav2.act{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/nav2_act.png) no-repeat 50% 0;}
# .tab_nav a.on .jihuo{display: block !important;}
# .tab_nav a.on .jihuo_no{display: none;}
# .prop_box{margin-top:80px;display: none;position: relative;}
# .wxz {width: 1241px;margin: 0px 0 0 -20px; }
# .tit1{background-position:-133px -28px;width: 753px;height: 156px;margin: 0 auto 40px;}
# .tit2{background-position:-137px -235px;width: 753px;height: 156px;margin: 0 auto 40px;}
# .prop11 {margin-left: -20px;}
# .prop .prop-pic4{ width: 326px; height: 278px;box-sizing: border-box;padding-top: 237px;margin: 0 auto;}
# .prop11 .prop-pic4{ width: 277px; height: 278px;box-sizing: border-box;padding-top: 237px;margin: 0 auto; }
# .list_prop li{float: left;width:259px;height: 279px; margin-right:10px;position: relative;text-align: center;box-sizing: border-box;padding-top: 235px;}
# .prop_box1 .list_prop .prop-pic1{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop1.png) no-repeat 50% 0; }
# .prop_box1 .list_prop .prop-pic2{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop2.png) no-repeat 50% 0; }
# .prop_box1 .list_prop .prop-pic3{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop3.png) no-repeat 50% 0; }
# .prop_box1 .prop-pic4{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop7.png) no-repeat 50% 0;}
# .prop_box2 .list_prop .prop-pic1{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop4.png) no-repeat 50% 0; }
# .prop_box2 .list_prop .prop-pic2{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop5.png) no-repeat 50% 0; }
# .prop_box2 .list_prop .prop-pic3{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop6.png) no-repeat 50% 0; }
# .prop_box2 .prop-pic4{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop8.png) no-repeat 50% 0;}
# .prop_box2 .list_prop .prop-pic5{ background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop10.png) no-repeat 50% 0; }
# .eng{width: 90px;height:28px;display: block;color:#1c1c1d;font-size:16px;line-height:30px;top: 10px;right:18px;}
# .eng1{color: #472f01;}
# .list_prop li p,.prop p{width:100%;color:#0f0f14;font-size:20px;}
# .list_prop1 li{width: 218px;height: 278px;margin-right: 5px !important;}
# .list_prop li .spe_txt{font-size:16px;line-height: 20px;}
# .btn_box{width: 723px;margin:24px auto;}
# .btn_box a{background-position:-1091px -164px;width: 360px;height: 77px;line-height:77px;color:#07f468;font-size:28px;font-family: "font"; text-align: center;}
# /*.prop_box2 .btn_box a{ background-position: -1117px -167px; }
# .btn_box a:hover{filter: brightness(1.06);}
# .btn_box a.btn_hui{background-position:-1457px -162px;}*/
# .txt1{display: block;color:#171717;font-size:20px;text-align: right;padding-top:0px;padding-right: 0px;background-color: #00ff68;
# width: 160px;height: 24px;line-height: 24px;text-align: center;position:absolute;right: 65px;top: 117px;}
# .prop .eng1{width:202px;text-align: center;}
# .prop p{text-align: center;width: 100%;}
# .btn_act{background-position:-1091px -164px;width: 360px;height: 77px; line-height:77px;color:#07f468;font-size:30px;font-family: "font"; text-align: center;display: block;margin: 24px auto 0;}
# /*.prop_box2 .btn_act{background-position:-1117px -167px;}*/
# .btn_act1{background-position:-979px -263px;width: 468px;height: 100px;line-height:100px;color:#151616;font-size:52px;font-family: "font";text-align: center;display: block;margin: 24px auto 0;}
# .btn_ok{background-position: -1109px -648px;width: 264px;height: 60px;margin: 24px auto 0;}
# .prop .btn_hui{background-position:-1458px -164px}
# /*part2*/
# .part2{margin:70px auto 55px;}
# .tit3{background-position: -112px -448px;width: 697px;height: 156px;margin: 150px auto 10px;}
# .prop1{margin:28px auto 0;}
# .part2 .btn_act{margin:0 auto;}
# .pop_txt{text-align: center;margin-top: 10px;font-size: 26px;}
# .pop_txt a{color: #07f468;font-size:22px;margin:0 30px;text-decoration: underline;}
# .txt{color:#07f468;font-size: 20px;text-align: center;line-height: 36px;height: 36px;}
# .lot {background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/lot.png)no-repeat 50% 0;;width: 1201px;height: 857px;position: relative;margin: 30px auto 0;}
# .btn_act1 {position: absolute;top: 330px;left: 50%;transform: translateX(-50%);}
# .lot .pop_txt {position: absolute;top: 460px;left: 50%;transform: translateX(-50%);z-index: 99;
# display: flex; justify-content: center; flex-wrap: wrap;width: 378px;flex-direction: row;   justify-content: space-between;}
# .lot .txt {color: #ffffff;}
# .lot .txt span{color: #07f468;}
# .qConnectLogin {z-index: 999;}
#
#
# /*part3*/
# .tit4{background-position:-65px -667px;width: 737px;height: 156px;margin: 180px auto 10px;}
# .list_rule{padding-left: 100px;margin-top:25px;}
# .list_rule li em{background-position:-1212px -521px;width: 15px;height: 17px;display: inline-block;vertical-align: top;margin-top: 8px;}
# .list_rule li span{color:#333333;font-size:20px;line-height: 38px;margin-left:12px;display: inline-block;width:1060px;}
# .list_rule li span strong{ color: #333333; }
# /*pop1*/
# .dialog{width: 840px;height:680px;padding-top:65px;display: none;}
#
# .pop1{ width: 589px; height: 659px; background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/pop1.png) no-repeat 50% 0;box-sizing: border-box;padding-top: 70px; }
# .dialog h3{height: 56px;margin: 0 auto;}
# .sub_tit1{width:127px;background-position:-532px -148px;}
# .txt2{color:#4c4950;font-size:18px;text-align: center;line-height: 38px;margin-top:30px;height:445px;}
# .txt2 span{display: inline-block;width:384px;padding-left:30px;}
# .txt2 span.last{width:370px;}
# .dia-close{background-position: -1452px -506px; width: 54px; height: 50px;position: absolute;top: 0;right:-50px;}
# /* .dia-close:hover{transform: rotate(180deg);} */
# /*pop3*/
# .pop3{ width: 589px; height: 559px; background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/pop3.png) no-repeat 50% 0;box-sizing: border-box;padding-top: 80px; }
# .sub_tit2{width:362px;background-position:-277px -231px;}
# .table{width:550px;margin:20px auto;}
# .table table{width:550px;text-align: center;}
# .table table th{font-size:26px;color: #4c4950;font-family: "font"; height: 30px;line-height: 30px;text-align: center;}
# .table table td{font-size:18px;color: #4c4950;height: 40px;}
# .page{margin:20px auto 0;width:550px;text-align: center;}
# .page a{width:100px;height: 40px; display: inline-block;color:#000000;font-size:24px;font-weight: bold;text-align: center;line-height:40px;vertical-align: middle;}
# .page span{color:#4c4950;font-size:24px;display: inline-block;vertical-align: middle;line-height: 32px;height: 32px;width:145px;text-align: center;}
# /*pop3*/
# .dialog1{background:url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/pop2.png) no-repeat 50% 0;width: 589px; height:569px;padding-top: 100px;}
# .dialog1 .txt2{margin: 0 auto;height: auto;text-align: center;font-size: 24px;}
#
# .pageprenone{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/sp.png) no-repeat 50% 0;}
# .pagepre{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/sp.png) no-repeat 50% 0;}
# .pagenextnone{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/sp.png) no-repeat 50% 0;}
# .pagenext{background: url(//game.gtimg.cn/images/fo4/cp/a20200520card/img/sp.png) no-repeat 50% 0;}
# .engx {width: 164px !important;}
# #pop3 .dia-con{padding-top:150px}
# </style>
# </head>
# <body>
# <div class="wrap">
# <div class="wrap1">
# 	<div class="container">
# 		<div class="head pr">
# 			<h1 class="db slo pa">
# 				<img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/slo.png" alt="ÈÙÒ«ÂÌÒðÔÂ¿¨" width="1195" height="579"/>
# 			</h1>
# 			<a href="/main.shtml" class="logo db pa" onclick="PTTSendClick('link','logo','FC Online');" target="_blank">FC Online</a>
# 			<!--<p class="tag pa"></p>
# 			<p class="tag1 pa"><span></span></p>-->
# 			<!--µÇÂ¼Ç°×´Ì¬ Start-->
# 			<div id="unlogin" class="login" style="display: block;">
# 				Ç×°®µÄÍæ¼Ò£¬Çë
# 				<a id="btn_qqlogin" href="javascript:void(0)" title="QQµÇÂ¼">¡¾µÇÂ¼¡¿</a>
# 			</div>
# 			<!--µÇÂ¼Ç°×´Ì¬ End-->
# 			<!--µÇÂ¼ºó×´Ì¬ Start-->
# 			<div id="logined" class="login" style="display: none;">
# 				»¶Ó­Äú£¬<span id="login_qq_span"></span>
#                 <span id="spanNotBind_669693">
#                     <a href="javascript:amsInit(308392, 669692);">[°ó¶¨´óÇø]</a>
#                 </span>
#                 <span id="spanBind_669693" style="display:none">
#                     <span id="area_info_669693"></span>
#                     <span id="role_info_669693"></span>
#                     <a href="javascript:amsInit(308392, 669692);">[¸ü¸Ä°ó¶¨]</a>
#                 </span>
# 				<a id="btn_logout" href="javascript:void(0)" title="×¢Ïú">¡¾×¢Ïú¡¿</a>
# 			</div>
# 			<!--µÇÂ¼ºó×´Ì¬ End-->
# 		</div>
# 		<div class="content">
# 			<div class="part1">
# 				<div class="tab_nav c">
# 					<!--¼¤»î¼ÓÀàÃûon-->
# 					<a href="javascript:;" onclick="PTTSendClick('btn','nav1','ÂÌÒðÔÂ¿¨')" class="nav1 fl on act">
# 						<p class="c"><span class="fr jihuo_no">Ê£ÓàÊ±¼ä£º<em class='day1'>0</em>Ìì</span><span class="fr jihuo" id='day1'>Î´¼¤»î</span></p>
# 						<!-- <span class="txt">ÂÌÒðÔÂ¿¨ºÍ´«ÆæÔÂ¿¨¿ÉÍ¬Ê±¹ºÂò£¬Í¬Ê±ÏíÊÜ·µ»¹</span> -->
# 					</a>
# 					<a href="javascript:;" onclick="PTTSendClick('btn','nav2','´«ÆæÔÂ¿¨')" class="nav2 fr">
# 						<p class="c"><span class="c jihuo fr">Ê£ÓàÊ±¼ä£º<em class='day2'>0</em>Ìì</span><span class="fr jihuo_no" id='day2'>Î´¼¤»î</span></p>
# 						<!-- <span class="txt">ÂÌÒðÔÂ¿¨ºÍ´«ÆæÔÂ¿¨¿ÉÍ¬Ê±¹ºÂò£¬Í¬Ê±ÏíÊÜ·µ»¹</span> -->
# 					</a>
# 				</div>
# 				<div class="prop_box prop_box1 c" style="display: block;">
# 					<h2 class="tit1 sp db">¼¤»îÂÌÒðÔÂ¿¨¿ÉÁ¢¼´»ñµÃ</h2>
# 					<span class="txt1"><!--½ñÈÕÁìÈ¡ºó<br />Ê£ÓàÊ±¼ä£º<em class='day1'>0</em>Ìì-->Î´¼¤»î</span>
# 					<div class="fl">
# 						<div class="prop_con">
# 							<ul class="list_prop c">
# 								<li class="prop-pic1">
# 									<em class="eng pa">Ö±½Ó»ñµÃ</em>
# 									<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop1.png" alt="4500µãÈ¯" width="249" height="247" /> -->
# 									<p>5000µãÈ¯</p>
# 								</li>
# 								<li class="prop-pic2">
# 									<em class="eng pa">Ö±½Ó»ñµÃ</em>
# 									<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop2.png" alt="45ÒÚBP" width="249" height="247" /> -->
# 									<p>100Õ×BP</p>
# 								</li>
# 								<li class="prop-pic3">
# 									<em class="eng eng1 pa">¶îÍâÔùËÍ</em>
# 									<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop3.png" alt="½ÖÇò´óÊ¹ÎäÀÚÇòÔ±°ü£¨5Ç¿£©" width="249" height="247" /> -->
# 									<p class="spe_txt">CCÈü¼¾TOP70ÇòÔ±°ü<br/>£¨7-8Ç¿£©¡Á1</p>
# 								</li>
# 							</ul>
# 							<div class="btn_box c">
# 								<!--ÖÃ»Òbtn_hui-->
# 								<a href="javascript:doBuySubmit(978016);" onclick="PTTSendClick('btn','buy1','¹ºÂòÔÂ¿¨')" class="sp fl buy1">¹ºÂòÔÂ¿¨£¨99Q±Ò£©</a>
# 								<a href="javascript:amsSubmit(308392,670444);" onclick="PTTSendClick('btn','act1','¼¤»î²¢ÁìÈ¡½±Àø')" class="sp fr act1">¼¤»î²¢ÁìÈ¡½±Àø</a>
# 							</div>
# 						</div>
# 					</div>
# 					<div class="fr">
# 						<div class="prop pr">
# 							<div class="prop-pic4">
# 								<em class="eng eng1 pa engx">Ã¿ÌìÁìÈ¡£¨30Ìì£©</em>
# 								<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop8.png" alt="500µãÈ¯" width="339" height="247" /> -->
# 								<p>500µãÈ¯</p>
# 							</div>
# 							<!--ÖÃ»Òbtn_hui-->
# 							<a href="javascript:amsSubmit(308392,669791);" onclick="PTTSendClick('btn','draw','ÁìÈ¡½ñÈÕ·µ»¹')" class="sp btn_act get1">ÁìÈ¡½ñÈÕ·µ»¹</a>
# 						</div>
# 					</div>
# 				</div>
# 				<div class="prop_box prop_box2 c">
# 					<h2 class="tit2 sp db">¼¤»î´«ÆæÔÂ¿¨¿ÉÁ¢¼´»ñµÃ</h2>
# 					<span class="txt1"><!--½ñÈÕÁìÈ¡ºó<br />Ê£ÓàÊ±¼ä£º<em class='day2'>0</em>Ìì-->Î´¼¤»î</span>
# 					<div class="wxz">
# 						<div class="fl">
# 							<div class="prop_con">
# 								<ul class="list_prop list_prop1 c">
# 									<li class="prop-pic1">
# 										<em class="eng pa">Ö±½Ó»ñµÃ</em>
# 										<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop4.png" alt="4500µãÈ¯" width="249" height="247" /> -->
# 										<p>10000µãÈ¯</p>
# 									</li>
# 									<li class="prop-pic2">
# 										<em class="eng pa">Ö±½Ó»ñµÃ</em>
# 										<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop5.png" alt="4500µãÈ¯" width="249" height="247" /> -->
# 										<p>300Õ×BP</p>
# 									</li>
# 									<li class="prop-pic3">
# 										<em class="eng eng1 pa">¶îÍâÔùËÍ</em>
# 										<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop6.png" alt="20WL¡¢19WL»ìºÏÇòÔ±°ü£¨102¼°ÒÔÉÏ£©" width="249" height="247" /> -->
# 										<p class="spe_txt">CCÈü¼¾TOP70ÇòÔ±°ü<br/>£¨8Ç¿£©¡Á2</p>
# 									</li>
# 									<li class="prop-pic5">
# 										<em class="eng eng1 pa">¶îÍâÔùËÍ</em>
# 										<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop6.png" alt="20WL¡¢19WL»ìºÏÇòÔ±°ü£¨102¼°ÒÔÉÏ£©" width="249" height="247" /> -->
# 										<p class="spe_txt">23HWÈü¼¾TOP50<br/>ÇòÔ±°ü£¨8Ç¿£©¡Á5</p>
# 									</li>
# 								</ul>
# 								<div class="btn_box c">
# 									<!--ÖÃ»Òbtn_hui-->
# 									<a href="javascript:doBuySubmit(978017);" onclick="PTTSendClick('btn','buy2','¹ºÂòÔÂ¿¨')" class="sp fl buy2">¹ºÂòÔÂ¿¨£¨198Q±Ò£©</a>
# 									<a href="javascript:amsSubmit(308392,670445);" onclick="PTTSendClick('btn','act2','¼¤»î²¢ÁìÈ¡½±Àø')" class="sp fr act2">¼¤»î²¢ÁìÈ¡½±Àø</a>
# 								</div>
# 							</div>
# 						</div>
# 						<div class="fr">
# 							<div class="prop prop11 pr">
# 								<div class="prop-pic4">
# 									<em class="eng eng1 pa">Ã¿ÌìÁìÈ¡£¨30Ìì£©</em>
# 									<!-- <img src="//game.gtimg.cn/images/fo4/cp/a20200520card/img/prop7.png" alt="500µãÈ¯" width="339" height="247" /> -->
# 									<p>1200µãÈ¯</p>
# 								</div>
# 								<!--ÖÃ»Òbtn_hui-->
# 								<a href="javascript:amsSubmit(308392,670443);" onclick="PTTSendClick('btn','draw1','ÁìÈ¡½ñÈÕ·µ»¹')" class="sp btn_act get2">ÁìÈ¡½ñÈÕ·µ»¹</a>
# 							</div>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="part2">
# 				<h2 class="tit3 sp db">Ò»·¢Èë»êÐÒÔËÀñºÐ</h2>
#
# 				<div class="lot pr" id="lotterycontent">
# 					<a href="javascript:void(0);" onclick="PTTSendClick('btn','lott','Ã¿ÈÕÒ»³é')" class="sp btn_act1">Ã¿ÈÕÒ»³é</a>
# 					<div class="pop_txt">
# 						<!--<a href="javascript:TGDialogS('pop1');" onclick="PTTSendClick('btn','show','²é¿´½±³Ø')">²é¿´½±³Ø</a>-->
# 						<p class="txt">½ñÈÕ¿É³éÈ¡£º<span class="lottory">0</span>´Î</p>
# 						<a href="javascript:amsSubmit(308392,670451);" onclick="PTTSendClick('btn','record','»ñ½±¼ÇÂ¼')">»ñ½±¼ÇÂ¼</a>
# 					</div>
#
# 				</div>
# 			</div>
# 			<div class="part3">
# 				<h2 class="tit4 sp db">»î¶¯¹æÔò</h2>
# 				<ul class="list_rule">
# 					<li><em class="sp"></em><span>ÔÂ¿¨·µ»¹ÈÕÆÚ¼ÆËã¹æÔò£º×ÔÔÂ¿¨¼¤»îÖ®ÈÕÆð£¬Ã¿ÌìµÇÂ¼ÓÎÏ·¼´¿ÉÁìÈ¡·µ»¹£¬<strong>¹²¼Æ30Ìì</strong>£»Èç6ÔÂ3ÈÕ¹ºÂòÔÂ¿¨²¢¼¤»î£¬ÔÂ¿¨·µ»¹ÉúÐ§ÆÚÎª£º<strong>6ÔÂ3ÈÕµ½7ÔÂ2ÈÕ£»</strong></span></li>
# 					<li><em class="sp"></em><span>ÔÂ¿¨Ã¿ÈÕ·µ»¹ºÍÁìÈ¡ÒªÇó£ºÔÚÔÂ¿¨¼¤»îºóµÄÉúÐ§ÆÚÄÚ£¬¡°½ñÈÕ·µ»¹¡±ÄÚÈÝÐèÔÚµ±ÈÕµÇÂ¼ÓÎÏ·ºó·½¿ÉÁìÈ¡£¬¹ýÆÚ²»Óè²¹³¥£»</span></li>
# 					<li><em class="sp"></em><span>ÂÌÒðÔÂ¿¨ºÍ´«ÆæÔÂ¿¨£¬µ¥QÔÚÁìÈ¡ÆÚ¼äÄÚÏÞ¹º1´Î£¬Á½Õß¿ÉÍ¬Ê±¹ºÂò£»</span></li>
# 					<li><em class="sp"></em><span>¼¤»îÔÂ¿¨ºó£¬Ã¿Ìì¿ÉÒÔÀ´µ½Ò³Ãæ²ÎÓëÒ»·¢Èë»êÐÒÔËºÐ³éÈ¡£¬ÂÌÒðÔÂ¿¨ºÍ´«ÆæÔÂ¿¨¿É·Ö±ðÁìÈ¡Ò»´Î£¬Á½ÖÖÔÂ¿¨³éÈ¡´ÎÊý¿Éµþ¼Ó£¬´ÎÈÕÇåÁã£»£¨ÁìÈ¡Ã¿ÈÕ·µ»¹ºó²Å¿É»ñµÃ³éÈ¡»ú»á£©</span></li>
# 					<li><em class="sp"></em><span>»î¶¯ÆÚ¼ä·µ»¹µÄµãÈ¯£¬²»»áÄÉÈë³äÖµÂú¶îµÄ¼ÆËã·¶³ë£»</span></li>
#                     <li><em class="sp"></em><span>±¾»î¶¯Îª³¤ÆÚ»î¶¯£¬ÔÂ¿¨½áÊøºó¿É¼ÌÐø¹ºÂò»ú»á£¬½±Àø¿ÉÖØ¸´ÁìÈ¡£»</span></li>
# 				</ul>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </div>
# <!--½±³Ø-->
# <div class="dialog pop1 pr" id="pop1">
#     <div class="dia-con">
#     	<!-- <h3 class="sub_tit1 sp db">½±³Ø</h3> -->
#     	<p class="txt2">
#     		<span>LOLÈü¼¾TOP100ÇòÔ±°ü£¨7-8Ç¿£©</span>
#     		<span class="last">5Õ×BP</span>
#     		<span>CAPÈü¼¾TOP100ÇòÔ±°ü£¨7-8Ç¿£©</span>
#     		<span class="last">BTBÈü¼¾TOP100ÇòÔ±°ü£¨6-8Ç¿£©</span>
#     		<span>3Õ×BP</span>
#     		<span class="last">FAÈü¼¾TOP100ÇòÔ±°ü£¨6-8Ç¿£©</span>
#     		<span>ÖÐ¹ú´«ÆæÈü¼¾ÇòÔ±°ü£¨5-8Ç¿£©</span>
#     		<span class="last">2Õ×BP</span>
#     		<span>22ÃûËÞÈü¼¾ÇòÔ±°ü£¨5-8Ç¿£©</span>
#     		<span class="last">1Õ×BP</span>
#     		<span>NTGÈü¼¾2022ÐÂÔöÇòÔ±°ü£¨1-8Ç¿£©</span>
#     		<span class="last">5000ÒÚBP</span>
#     	</p>
# 		<a href="javascript:closeDialog();" onclick="PTTSendClick('btn','ok1','È·¶¨')" class="sp btn_act btn_ok"></a>
#     </div>
#     <a class="dia-close sp db" href="javascript:closeDialog()" title="¹Ø±Õ">¡Á</a>
# </div>
# <!--»ñ½±¼ÇÂ¼-->
# <div class="dialog pop3 pr" id="showMyGiftContent_670451">
#     <div class="dia-con">
#     	<!-- <h3 class="sub_tit2 sp db">»ñ½±¼ÇÂ¼</h3> -->
#     	<div class="table">
# 			<!-- Ò»Ò³×î¶à8¸ö -->
#     		<table>
#     			<tr>
#     				<th width="220">Ê±¼ä</th>
#     				<th>Ãû³Æ</th>
#     			</tr>
#                 <tbody id="getGiftContent_670451">
# 				</tbody>
#     		</table>
#     		<div class="page" id="getGiftPageContent_670451">
#     			<!-- <a href="javascript:;" onclick="PTTSendClick('btn','prev','ÉÏÒ»Ò³')">ÉÏÒ»Ò³</a>
#     			<span><em>1</em>/<em>3</em></span>
#     			<a href="javascript:;" onclick="PTTSendClick('btn','next','ÏÂÒ»Ò³')">ÏÂÒ»Ò³</a> -->
#     		</div>
#     	</div>
#     </div>
#     <a class="dia-close sp db" href="javascript:myGiftList_670451.close()" title="¹Ø±Õ">¡Á</a>
# </div>
# <script type="text/html" id="getGiftTemplate_670451">
# {if MyGiftListObject.iRet!='0'}
# 	<tr>
# 		<td colspan="2" align="center">${MyGiftListObject.sMsg}</td>
# 	</tr>
# {else}
# 	{for giftInfo in MyGiftListObject.myGiftList}
# 		<tr>
# 			<td>${giftInfo.getTime}</td>
# 			<td>${giftInfo.packageName}</td>
# 		</tr>
# 	{forelse}
# 		<tr>
# 			<td colspan="2" align="center">ÄúÉÐÎ´»ñµÃÈÎºÎÀñ°ü</td>
# 		</tr>
# 	{/for}
# {/if}
# </script>
# <!--¹§Ï²»ñ½±-->
# <div class="dialog dialog1 pr" id="pop3">
#     <div class="dia-con">
#     	<!-- <h3 class="hide">¹§Ï²Äã»ñµÃÁË½±Àø</h3> -->
# 		<div class="txt-box">
# 			<p class="txt2">xxxxxxxxxxx</p>
# 		</div>
# 		<a href="javascript:closeDialog();" onclick="PTTSendClick('btn','ok2','È·¶¨')" class="sp btn_act btn_ok"></a>
#     </div>
#     <a class="dia-close sp db" href="javascript:closeDialog()" title="¹Ø±Õ">¡Á</a>
# </div>
# <script src="//ossweb-img.qq.com/images/js/jquery/jquery-1.11.3.min.js"></script>
# <script type="text/javascript">
# 	var basejs = [
# 		'//ossweb-img.qq.com/images/js/jquery/jquery-1.11.3.min.js',
# 		'//ossweb-img.qq.com/images/js/milo_bundle/milo.js'
# 	];
#
# 	var _isMobile_ = function(){
# 		return /iphone|ios|android|mini|mobile|mobi|Nokia|Symbian|iPod|iPad|Windows\s+Phone|MQQBrowser|wp7|wp8|UCBrowser7|UCWEB|360\s+Aphone\s+Browser|blackberry/i.test(navigator.userAgent);
# 	}
# 	if(_isMobile_()){
# 		basejs = [
# 			'//ossweb-img.qq.com/images/js/mobile_bundle/util/zepto-all.js',
# 			'//ossweb-img.qq.com/images/js/mobile_bundle/milo.js',
# 			'//ossweb-img.qq.com/images/js/TGMobileShare/TGMobileShare.min.js'
# 		]
# 	}
# 	for (var i = 0; i < basejs.length; i++) {
# 		document.write('<script type="text/javascript" src="' + basejs[i] + '"></s'+'cript>');
# 	}
# 	</script>
#
#
# <!--script type="text/javascript" src="//ossweb-img.qq.com/images/js/milo/milo.js"></script-->
# <script src="//ossweb-img.qq.com/images/js/title.js"></script>
# <script charset="gbk"src="/common/top.js"></script>
# <script src="//game.gtimg.cn/images/js/2018foot/foot.js"></script>
# <script type="text/javascript" src="//ossweb-img.qq.com/images/ams/atm/reporting.js?action=308392"></script>
# <!--script type="text/javascript" src="//ossweb-img.qq.com/images/js/x8/user_report.js" iModuleId="10258" iActivityId="308392" iFlowId="669745"></script-->
# <script src="//game.gtimg.cn/images/js/delottery/lottery.js"></script>
# <script src="index.js"></script>
# <script>
# 	(function(){
#         window.shareIcon = 'https://game.gtimg.cn/images/fo4/cp/a20200520card/img/fco_share1.png';
# 		/*var today = parseInt(milo.getSeverDateTime().getTime() / 1000, 10);
# 		var startDay = parseInt((new Date('2023/09/20').getTime()) / 1000, 10);
# 		window.description = $("head [name='Description']").attr('content');
# 		window.keywords = $("head [name='Keywords']").attr('content');;
# 		window.title = $("head title").text();
#
#         window.logourl = 'https://game.gtimg.cn/images/fo4/cp/a20200520card/img/logo_fco.png';
# 		if(window.location.hostname == "fco.qq.com" || today >= startDay){
#             window.description = '¡¶FC Online¡·¹Ù·½ÍøÕ¾¡£EA SPORTS FCÑÐ·¢£¬ÌÚÑ¶ÓÎÏ·´úÀíÔËÓªµÄÈ«Çò×îÊÜ»¶Ó­ÕæÊµ3D×ãÇòÍøÓÎÏµÁÐ£¬ÓµÓÐ±ÆÕæµÄÇòÔ±ÐÎÏó£¬·á¸»µÄÇòÔ±Çò¶ÓÑø³É£¬¿ìËÙÆ¥ÅäÈ«ÇòÍæ¼Ò£¬´ø¸øÄã³¬ÄâÕæÂÌÒðÀÖÈ¤¡£';
# 			window.keywords = 'FC Online,FC Online¹Ù·½ÏÂÔØ,FC OnlineÏÂÔØ,×ãÇòÔÚÏß,FC Online,3D,×ãÇò,ÍøÓÎ,ÌåÓý,ÊÀ½ç±­,Å·¹Ú,ÖÐ³¬,ÇòÔ±,Ã·Î÷,CÂÞ,ÄÚÂí¶û,×ª»á,µç×Ó¾º¼¼,ÌÚÑ¶,ÍøÂçÓÎÏ·';
# 			window.title = 'FC Online×ãÇòÔÚÏß¹Ù·½ÍøÕ¾-ÌÚÑ¶ÓÎÏ·-ÈÈ°®ÐÂÉú';
# 			window.shareIcon = 'https://game.gtimg.cn/images/fo4/cp/a20200520card/img/fco_share.png';
# 			$("head [name='Description']").attr('content', window.description);
# 			$("head [name='Keywords']").attr('content', window.keywords);
# 			$("head title").text(window.title);
#             $(".logo").css("background","url("+ window.logourl +")").attr({'title':'fco'}).text('fco');
# 		}*/
# 		if(_isMobile_()){
# 			TGMobileShare({
# 				//²»ÉèÖÃ»òÉèÖÃÎª¿ÕÊ±£¬Ò³ÃæÓÐtitle£¬Ôòµ÷È¡title
# 				shareTitle:window.title,
# 				//²»ÉèÖÃ»òÉèÖÃÎª¿ÕÊ±£¬Ò³ÃæÓÐDescription£¬Ôòµ÷È¡Description
# 				shareDesc:window.description,
# 				//·ÖÏíÍ¼Æ¬³ß´ç200*200£¬´óÐ¡¿ØÖÆÔÚ10k×óÓÒ£¬ÇÒÌîÐ´¾ø¶ÔÂ·¾¶
# 				shareImgUrl:window.shareIcon,
# 				//·ÖÏíÁ´½ÓÒª¸úµ±Ç°Ò³ÃæÍ¬ÓòÃû(ÊÖQ·ÖÏíÓÐÕâ¸öÒªÇó) ,²»ÉèÖÃ»òÉèÖÃÎª¿ÕÊ±£¬Ä¬ÈÏµ÷È¡µ±Ç°URL
# 				shareLink:window.location.href,
# 				//µã»÷Á÷ÃüÃû£¬a20170812aqzx£¬×¨ÌâÒ»°ã²ÉÓÃÄ¿Â¼Ãû³ÆÈça20151029demo
# 				actName:'a20200520card',
# 				//³õÊ¼»¯Íê³ÉµÄ»Øµ÷·½·¨£¬tgms²ÎÊýÎªObjectÀàÐÍ£¬ÓÐisWX£¬isQQ£¬fileName£¬tcssNameËÄ¸öÊôÐÔ
# 				onInit:function(tgms){
# 				//alert('·ÖÏíÐÅÏ¢ÉèÖÃÍê±ÏÀ²£¡\nµ±Ç°ÊÇ·ñÊÇÎ¢ÐÅ·ÃÎÊ£º\n'   +tgms.isWX+   '\nµ±Ç°ÊÇ·ñÊÇÊÖQ·ÃÎÊ£º\n' +  tgms.isQQ  + '\nµ±Ç°ÎÄ¼þÃû(³ýÈ¥À©Õ¹Ãû)Îª£º\n'  + tgms.fileName   +'\nµ±Ç°tcssµã»÷Á÷ÃüÃûÇ°×ºÎª£º\n'  + tgms.tcssName +  '\nµ±Ç°ÊÖ»úÏµÍ³Îª£º\n'  + tgms.osType);
# 				}
# 			});
# 		}
# 	})()
#
#
# </script>
# <script>
# function TGDialogS(e) {
# 	// ÀûÓÃmilo¿âÒýÈëdialog×é¼þ
# 	need("biz.dialog", function(Dialog) {
# 		Dialog.show({
# 			id: e,
# 			bgcolor: '#000', //µ¯³ö¡°ÕÚÕÖ¡±µÄÑÕÉ«£¬¸ñÊ½Îª"#FF6600"£¬¿ÉÐÞ¸Ä£¬Ä¬ÈÏÎª"#fff"
# 			opacity:70 //µ¯³ö¡°ÕÚÕÖ¡±µÄÍ¸Ã÷¶È£¬¸ñÊ½Îª£û10-100£ý£¬¿ÉÑ¡
# 		});
# 	});
# }
# function closeDialog() {
# 	// ÀûÓÃmilo¿âÒýÈëdialog×é¼þ
# 	need("biz.dialog", function(Dialog) {
# 		Dialog.hide();
# 	});
# }
# //TABÇÐ»»
# function switchFun(btn, dom) {
# 	$(btn).on("click", function() {
# 		if($(this).hasClass('act')) {
# 			return;
# 		}
# 		$(this).addClass('act').siblings().removeClass('act');
# 		$(dom).hide();
# 		$(dom).eq($(this).index()).show();
# 	})
# }
# switchFun(".tab_nav a", ".prop_box");
# //µÇÂ¼
# milo.ready(function () {
#     window.iUseQQConnect=1;//2023-09-06 myinÐÂÔö»¥ÁªµÇÂ¼
#     need("biz.login",function(LoginManager){
#         //QQµÇÂ¼
#         milo.addEvent(g('btn_qqlogin'),'click',function(e){
#             LoginManager.login();
#         });
#
#         //×¢Ïú
#         milo.addEvent(g("btn_logout"),"click",function(){
#            // LoginManager.logout();
#            need("biz.login",function(LoginManager){
#                 $("#unlogin").show();
# 		        $("#logined").hide();
# 		        $("#login_qq_span").text('');
#                LoginManager.logout();
#                location.reload();
# 		    });
#         })
#
#
#
#         LoginManager.checkLogin(function(userinfo){
#             $("#login_qq_span").text(userinfo.nickname);
#             // g("login_qq_span").innerText= LoginManager.getUserUin();//»ñÈ¡QQºÅ
#             $("#unlogin").hide();
#             $("#logined").show();
#             amsInit(308392, 669693);
#         },function(){
#             LoginManager.init({
#                 needReloadPage:true
#             });
#             LoginManager.login(function(res){
#                 var nickName = LoginManager.getNickName();
#                 $("#login_qq_span").text(nickName);
#                 console.log('ÒÑµÇÂ¼-------------!');
#                 console.log(nickName)
#                 $("#unlogin").hide();
#                 $("#logined").show();
#                 amsInit(308392, 669693);
#             },
#             {
#                     iUseQQConnect:1,//ÊÇ·ñÊ¹ÓÃQQ»¥Áª
#                     //»¥ÁªµÇÂ¼²ÎÊý
#                     'oQQConnectParams':{
#                         appId:"101491592",//Èç¹ûÓÃÄ¬ÈÏappid:101491592£¬Ôò¿ÉÒÔ²»ÓÃÌî
#                         scope:"get_user_info",
#                         state:"STATE",
#                         s_url:window.location.href,
#                         redirect_uri:"https://milo.qq.com/comm-htdocs/login/qc_redirect.html"//Èç¹ûÓÃÄ¬ÈÏappid:101491592£¬Ôò¿ÉÒÔ²»ÓÃÌî
#                     }
#             });
#         });
#
# 		/*LoginManager.checkLogin(function(userinfo){
# 			var acctype = milo.cookie.get("acctype");
#             if(acctype == 'qc' && typeof(HostApp) === 'undefined'){
#                 LoginManager.logout({
#                     logoutCallback:function () {
#                         setTimeout(function(){
#                             window.location.reload(true);
#                         },2000);
#                     }
#                 });
#                 return;
#             }
# 			amsInit(308392, 669693);
# 		});*/
#     });
# });
# </script>
# <script src="//ossweb-img.qq.com/images/js/PTT/ping_tcss_tgideas_https_min.js"></script>
# <script>
# //´Ë¶Î´úÂë²»ÄÜ·Åµ½ÍâÁ´JSÖÐ£¬
# var setSite={ //ÉèÖÃÍøÕ¾ÊôÐÔ
#     siteType:"a20200520card", //±ØÌîÏî:"os"´ú±íÊÇ¹ÙÍø£¬Èç¹û²»ÊÇ£¬ÔòÌîÐ´actNameÀýÈça20160701xxx
#     pageType:"index", //±ØÌîÏî:±¾Ò³ÃæµÄ¶¨Î»£»°´ÕÕÒ³Ãæº¬ÒåÌîÐ´ÀýÈçmain||list||detail||download||share||page1||pageN
#     pageName:"Ê×Ò³", //±ØÌîÏî:Ò³ÃæÖÐÎÄÃû
#     project:"other" //Ñ¡ÌîÏî:Èç¹ûÊÇ¹ÙÍøÄ£¿éÔòÊÇ±ØÌî;°´ÕÕÄ£¿éÄÚÈÝ£¬ÌîÐ´¹Ì¶¨µÄ¶ÔÓ¦Öµ;Ô­Éú¹ÙÍøbase;Î¢ÉçÇøingame;Í¬ÈËÕ¾doujin;ÈüÊÂmatch;¹ÊÊÂÕ¾story;ÎÄ»¯Õ¾history;·ÛË¿Õ¾fans;±¬ÁÏÕ¾co
# }
# </script>

# %%
# !pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Obtaining dependency information for webdriver-manager from https://files.pythonhosted.org/packages/b1/51/b5c11cf739ac4eecde611794a0ec9df420d0239d51e73bc19eb44f02b48b/webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata
#   Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests in c:\users\junjie\anaconda3\lib\site-packages (from webdriver-manager) (2.31.0)
# Requirement already satisfied: python-dotenv in c:\users\junjie\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\junjie\anaconda3\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\junjie\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\junjie\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\junjie\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\junjie\anaconda3\lib\site-packages (from requests->webdriver-manager) (2024.2.2)
# Downloading webdriver_manager-4.0.1-py2.py3-none-any.whl (27 kB)
# Installing collected packages: webdriver-manager
# Successfully installed webdriver-manager-4.0.1

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# 设置Selenium WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 打开网页
driver.get('https://fco.qq.com/cp/a20200520card/index.html')

# 等待页面加载完成
driver.implicitly_wait(10) # 10秒内每隔一段时间检查一次页面是否加载完成

try:
    # 定位“领取今日返还”按钮，这里假设按钮有一个唯一的ID 'receiveButton'
    receive_button = driver.find_element(By.ID, 'receiveButton')
    
    # 点击按钮
    receive_button.click()
    
    # 等待一会儿以便完成操作
    driver.implicitly_wait(5)
finally:
    # 关闭浏览器
    driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# 设置Selenium WebDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# 打开网页
# 打开网页
driver.get('https://fco.qq.com/cp/a20200520card/index.html')
# 假设你已经设置了ChromeDriver的路径和初始化了driver变量

driver.maximize_window()  # 浏览器窗口最大化

# 切换到包含登录按钮的iframe
sd = driver.switch_to.frame(driver.find_element(By.ID, "loginIframe"))
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[4], line 17
#      14 driver.maximize_window()  # 浏览器窗口最大化
#      16 # 切换到包含登录按钮的iframe
# ---> 17 sd = driver.switch_to.frame(driver.find_element(By.ID, "loginIframe"))
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="loginIframe"]"}
#   (Session info: chrome=121.0.6167.185); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x0120E123+48179]
# 	(No symbol) [0x01195D01]
# 	(No symbol) [0x0107D72D]
# 	(No symbol) [0x010B572B]
# 	(No symbol) [0x010B586B]
# 	(No symbol) [0x010EC5B2]
# 	(No symbol) [0x010D3CD4]
# 	(No symbol) [0x010EAA1E]
# 	(No symbol) [0x010D3A26]
# 	(No symbol) [0x010AB7BC]
# 	(No symbol) [0x010AC62D]
# 	GetHandleVerifier [0x01527C33+3299139]
# 	GetHandleVerifier [0x01565BF2+3553026]
# 	GetHandleVerifier [0x01560BCC+3532508]
# 	GetHandleVerifier [0x012A494E+664670]
# 	(No symbol) [0x011A0AB4]
# 	(No symbol) [0x0119BF08]
# 	(No symbol) [0x0119C02D]
# 	(No symbol) [0x0118DD00]
# 	BaseThreadInitThunk [0x76537BA9+25]
# 	RtlInitializeExceptionChain [0x77C4BD2B+107]
# 	RtlClearBits [0x77C4BCAF+191]

# %%
# !pip install --upgrade selenium
# Out:
# Requirement already satisfied: selenium in c:\users\junjie\anaconda3\lib\site-packages (4.17.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\junjie\anaconda3\lib\site-packages (from selenium) (1.26.16)
# Requirement already satisfied: trio~=0.17 in c:\users\junjie\anaconda3\lib\site-packages (from selenium) (0.24.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\junjie\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\junjie\anaconda3\lib\site-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\junjie\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (22.1.0)
# Requirement already satisfied: sortedcontainers in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\junjie\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\junjie\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\junjie\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\junjie\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\junjie\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# 设置Selenium WebDriver
driver = webdriver.Chrome(ChromeDriverManager().install())

# 打开网页
driver.get('https://fco.qq.com/cp/a20200520card/index.html')


# 等待页面加载
driver.implicitly_wait(10)

# 定位用户名和密码输入框
# 假设输入框有特定的id或name
username_input = driver.find_element(By.ID, 'username_input_id')
password_input = driver.find_element(By.ID, 'password_input_id')

# 输入用户名和密码
username_input.send_keys('your_username')
password_input.send_keys('your_password')

# 定位登录按钮并点击
# 假设按钮有特定的id
login_button = driver.find_element(By.ID, 'login_button_id')
login_button.click()

# 等待一会儿以便登录完成
driver.implicitly_wait(5)
# Out:
# "\n# 等待页面加载\ndriver.implicitly_wait(10)\n\n# 定位用户名和密码输入框\n# 假设输入框有特定的id或name\nusername_input = driver.find_element(By.ID, 'username_input_id')\npassword_input = driver.find_element(By.ID, 'password_input_id')\n\n# 输入用户名和密码\nusername_input.send_keys('your_username')\npassword_input.send_keys('your_password')\n\n# 定位登录按钮并点击\n# 假设按钮有特定的id\nlogin_button = driver.find_element(By.ID, 'login_button_id')\nlogin_button.click()\n\n# 等待一会儿以便登录完成\ndriver.implicitly_wait(5)\n\n"

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

# 设置Selenium WebDriver
driver = webdriver.Chrome(ChromeDriverManager().install())

# 打开登录页面
driver.get('https://fco.qq.com/cp/a20200520card/index.html'

# 等待页面加载
driver.implicitly_wait(10)

# 定位用户名和密码输入框
# 假设输入框有特定的id或name
username_input = driver.find_element(By.ID, 'username_input_id')
password_input = driver.find_element(By.ID, 'password_input_id')

# 输入用户名和密码
username_input.send_keys('your_username')
password_input.send_keys('your_password')

# 定位登录按钮并点击
# 假设按钮有特定的id
login_button = driver.find_element(By.ID, 'login_button_id')
login_button.click()

# 等待一会儿以便登录完成
driver.implicitly_wait(5)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:711, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     710 if is_new_proxy_conn and http_tunnel_required:
# --> 711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1007, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1005     conn.tls_in_tls_required = True
# -> 1007 conn.connect()
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#
# File ~\anaconda3\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File ~\anaconda3\Lib\ssl.py:1108, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1107             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1108         self.do_handshake()
#    1109 except (OSError, ValueError):
#
# File ~\anaconda3\Lib\ssl.py:1379, in SSLSocket.do_handshake(self, block)
#    1378         self.settimeout(None)
# -> 1379     self._sslobj.do_handshake()
#    1380 finally:
#
# ConnectionResetError: [WinError 10054] 远程主机强迫关闭了一个现有的连接。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:798, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     796     e = ProtocolError("Connection aborted.", e)
# --> 798 retries = retries.increment(
#     799     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     800 )
#     801 retries.sleep()
#
# File ~\anaconda3\Lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='googlechromelabs.github.io', port=443): Max retries exceeded with url: /chrome-for-testing/latest-patch-versions-per-build.json (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\http.py:32, in WDMHttpClient.get(self, url, **kwargs)
#      31 try:
# ---> 32     resp = requests.get(
#      33         url=url, verify=self._ssl_verify, stream=True, **kwargs)
#      34 except exceptions.ConnectionError:
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:513, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     512 if isinstance(e.reason, _ProxyError):
# --> 513     raise ProxyError(e, request=request)
#     515 if isinstance(e.reason, _SSLError):
#     516     # This branch is for urllib3 v1.22 and later.
#
# ProxyError: HTTPSConnectionPool(host='googlechromelabs.github.io', port=443): Max retries exceeded with url: /chrome-for-testing/latest-patch-versions-per-build.json (Caused by ProxyError('Cannot connect to proxy.', ConnectionResetError(10054, '远程主机强迫关闭了一个现有的连接。', None, 10054, None)))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[13], line 7
#       4 from webdriver_manager.chrome import ChromeDriverManager
#       6 # 设置Selenium WebDriver
# ----> 7 driver = webdriver.Chrome(ChromeDriverManager().install())
#       9 # 打开登录页面
#      10 driver.get('https://fco.qq.com/cp/a20200520card/index.html')
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\chrome.py:40, in ChromeDriverManager.install(self)
#      39 def install(self) -> str:
# ---> 40     driver_path = self._get_driver_binary_path(self.driver)
#      41     os.chmod(driver_path, 0o755)
#      42     return driver_path
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\manager.py:35, in DriverManager._get_driver_binary_path(self, driver)
#      34 def _get_driver_binary_path(self, driver):
# ---> 35     binary_path = self._cache_manager.find_driver(driver)
#      36     if binary_path:
#      37         return binary_path
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver_cache.py:108, in DriverCacheManager.find_driver(self, driver)
#     105 driver_version = self.get_cache_key_driver_version(driver)
#     106 metadata = self.load_metadata_content()
# --> 108 key = self.__get_metadata_key(driver)
#     109 if key not in metadata:
#     110     log(f'There is no [{os_type}] {driver_name} "{driver_version}" for browser {browser_type} '
#     111         f'"{browser_version}" in cache')
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver_cache.py:142, in DriverCacheManager.__get_metadata_key(self, driver)
#     139 if self._metadata_key:
#     140     return self._metadata_key
# --> 142 driver_version = self.get_cache_key_driver_version(driver)
#     143 browser_version = driver.get_browser_version_from_os()
#     144 browser_version = browser_version if browser_version else ""
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver_cache.py:152, in DriverCacheManager.get_cache_key_driver_version(self, driver)
#     150 if self._cache_key_driver_version:
#     151     return self._cache_key_driver_version
# --> 152 return driver.get_driver_version_to_download()
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\driver.py:48, in Driver.get_driver_version_to_download(self)
#      45 if self._driver_version_to_download:
#      46     return self._driver_version_to_download
# ---> 48 return self.get_latest_release_version()
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\drivers\chrome.py:59, in ChromeDriver.get_latest_release_version(self)
#      57 if determined_browser_version is not None and version.parse(determined_browser_version) >= version.parse("115"):
#      58     url = "https://googlechromelabs.github.io/chrome-for-testing/latest-patch-versions-per-build.json"
# ---> 59     response = self._http_client.get(url)
#      60     response_dict = json.loads(response.text)
#      61     determined_browser_version = response_dict.get("builds").get(determined_browser_version).get("version")
#
# File ~\anaconda3\Lib\site-packages\webdriver_manager\core\http.py:35, in WDMHttpClient.get(self, url, **kwargs)
#      32     resp = requests.get(
#      33         url=url, verify=self._ssl_verify, stream=True, **kwargs)
#      34 except exceptions.ConnectionError:
# ---> 35     raise exceptions.ConnectionError(f"Could not reach host. Are you offline?")
#      36 self.validate_response(resp)
#      37 return resp
#
# ConnectionError: Could not reach host. Are you offline?

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# 设置Selenium WebDriver
driver = webdriver.Chrome(ChromeDriverManager().install())

# 打开网页
driver.get('https://fco.qq.com/cp/a20200520card/index.html')

# 等待页面加载
driver.implicitly_wait(10)

# 点击登录按钮
# login_button = driver.find_element(By.ID, 'btn_qqlogin')
# login_button.click()

# 如果登录表单是在新窗口或新标签页中打开的，您可能需要切换到那个窗口
# driver.switch_to.window(driver.window_handles[1])

# 如果登录表单是在iframe中的，您需要先切换到那个iframe
# driver.switch_to.frame(driver.find_element_by_tag_name("iframe"))

# 接下来填写用户名和密码，点击登录
# 注意：这一步骤可能需要根据实际页面结构调整

# %% [markdown]
# # csdn上面的代码

# %%
System.setProperty("webdriver.chrome.driver", "C:\\Program Files\\Google\\Chrome\\Application\\chromedriver.exe");

        ChromeDriverProxy driver = null;

        ChromeOptions options = new ChromeOptions();
        options.addArguments("--disable-popup-blocking"); // 禁用阻止弹出窗口
        options.addArguments("no-sandbox"); // 启动无沙盒模式运行
        options.addArguments("disable-extensions"); // 禁用扩展
        options.addArguments("no-default-browser-check"); // 默认浏览器检查
        Map<String, Object> prefs = new HashMap();
        prefs.put("credentials_enable_service", false);
        prefs.put("profile.password_manager_enabled", false);// 禁用保存密码提示框
        options.setExperimentalOption("prefs", prefs);

        // set performance logger
        // this sends Network.enable to chromedriver
        LoggingPreferences logPrefs = new LoggingPreferences();
        logPrefs.enable(LogType.PERFORMANCE, Level.ALL);
        logPrefs.enable(LogType.BROWSER, Level.ALL);
        options.setCapability(CapabilityType.LOGGING_PREFS, logPrefs);
        options.setExperimentalOption("w3c", false);
        // if your wantn't open the chrome head, you can set it true.
// options.setHeadless(true);

        driver = new ChromeDriverProxy(options);
        driver.get("https://lol.qq.com/space/index.shtml");
// login.
        driver.manage().window().maximize();
        WebDriver sd = driver.switchTo().frame(driver.findElement(By.id("loginIframe")));
        WebElement sw = sd.findElement(By.id("switcher_plogin"));
        sw.click();
        driver.findElement(By.id("u")).sendKeys("your qq number");
        driver.findElement(By.id("p")).sendKeys("your qq password");
        driver.findElement(By.id("login_button")).click();
        System.out.println(driver.getCurrentUrl());

// select the lol area.
        Thread.sleep(2000);
        WebElement area = driver.findElement(By.id("areaContentId_lol"));
        Select select = new Select(area);
        select.selectByValue("19");
        driver.findElement(By.id("roleselecterlol")).click();
        Thread.sleep(2000);
        area.click();
        driver.findElement(By.id("confirmButtonId_lol")).click();
        Thread.sleep(1500);
        
        // get cookie.
        String newWindowUrl = "https://game.qq.com/";
        driver.get(newWindowUrl);
        driver.manage().getCookies().stream().forEach(c -> System.out.println(c.toString()));
        driver.manage().getCookies().stream().forEach(c -> System.out.println(c.getName() + "\t" + c.getValue()));
        pSkey = driver.manage().getCookieNamed("p_skey").getValue();
        System.out.println(pSkey);
        System.out.println(driver.manage().getCookieNamed("skey").getValue());
# Out:
#   Cell In[2], line 3
#     ChromeDriverProxy driver = null;
#     ^
# IndentationError: unexpected indent
